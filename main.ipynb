# %%
import pandas as pd
import marimo as mo
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dl

df = pd.read_excel(R"C:\Users\TAJ\Desktop\world_economic_report\WorldBank.xlsx").rename({"Country Name": "Country"}, axis=1)

# %%
pip install marimo
# Out:
# Requirement already satisfied: marimo in c:\users\taj\anaconda3\lib\site-packages (0.18.4)
# Requirement already satisfied: click<9,>=8.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (8.1.7)
# Requirement already satisfied: jedi>=0.18.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (0.18.1)
# Requirement already satisfied: markdown<4,>=3.6 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (3.10)
# Requirement already satisfied: pymdown-extensions<11,>=10.15 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (10.20)
# Requirement already satisfied: pygments<3,>=2.19 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (2.19.2)
# Requirement already satisfied: tomlkit>=0.12.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (0.13.3)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (6.0.1)
# Requirement already satisfied: uvicorn>=0.22.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (0.40.0)
# Requirement already satisfied: starlette!=0.36.0,>=0.35.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (0.50.0)
# Requirement already satisfied: websockets>=14.2.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (15.0.1)
# Requirement already satisfied: loro>=1.5.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (1.10.3)
# Requirement already satisfied: docutils>=0.16.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (0.18.1)
# Requirement already satisfied: psutil>=5.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (5.9.0)
# Requirement already satisfied: itsdangerous>=2.0.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (2.2.0)
# Requirement already satisfied: narwhals>=2.0.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (2.0.1)
# Requirement already satisfied: packaging in c:\users\taj\anaconda3\lib\site-packages (from marimo) (23.2)
# Requirement already satisfied: msgspec>=0.20.0 in c:\users\taj\anaconda3\lib\site-packages (from marimo) (0.20.0)
# Requirement already satisfied: colorama in c:\users\taj\anaconda3\lib\site-packages (from click<9,>=8.0->marimo) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\taj\anaconda3\lib\site-packages (from jedi>=0.18.0->marimo) (0.8.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\taj\anaconda3\lib\site-packages (from starlette!=0.36.0,>=0.35.0->marimo) (4.2.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\taj\anaconda3\lib\site-packages (from starlette!=0.36.0,>=0.35.0->marimo) (4.11.0)
# Requirement already satisfied: h11>=0.8 in c:\users\taj\anaconda3\lib\site-packages (from uvicorn>=0.22.0->marimo) (0.14.0)
# Requirement already satisfied: idna>=2.8 in c:\users\taj\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette!=0.36.0,>=0.35.0->marimo) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\taj\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette!=0.36.0,>=0.35.0->marimo) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#        Country Country Code      Region IncomeGroup  Year  \
# 0  Afghanistan          AFG  South Asia  Low income  2018
# 1  Afghanistan          AFG  South Asia  Low income  2017
# 2  Afghanistan          AFG  South Asia  Low income  2016
# 3  Afghanistan          AFG  South Asia  Low income  2015
# 4  Afghanistan          AFG  South Asia  Low income  2014
#
#    Birth rate, crude (per 1,000 people)  Death rate, crude (per 1,000 people)  \
# 0                                   NaN                                   NaN
# 1                                33.211                                 6.575
# 2                                33.981                                 6.742
# 3                                34.809                                 6.929
# 4                                35.706                                 7.141
#
#    Electric power consumption (kWh per capita)     GDP (USD)  \
# 0                                          NaN  1.936300e+10
# 1                                          NaN  2.019180e+10
# 2                                          NaN  1.936260e+10
# 3                                          NaN  1.990710e+10
# 4                                          NaN  2.048490e+10
#
#    GDP per capita (USD)  Individuals using the Internet (% of population)  \
# 0               520.897                                               NaN
# 1               556.302                                             13.50
# 2               547.228                                             11.20
# 3               578.466                                              8.26
# 4               613.856                                              7.00
#
#    Infant mortality rate (per 1,000 live births)  \
# 0                                           47.9
# 1                                           49.5
# 2                                           51.2
# 3                                           53.1
# 4                                           55.1
#
#    Life expectancy at birth (years)  \
# 0                               NaN
# 1                            64.130
# 2                            63.763
# 3                            63.377
# 4                            62.966
#
#    Population density (people per sq. km of land area)  \
# 0                                            56.9378
# 1                                            55.5960
# 2                                            54.1971
# 3                                            52.7121
# 4                                            51.1148
#
#    Unemployment (% of total labor force) (modeled ILO estimate)
# 0                                              1.542
# 1                                              1.559
# 2                                              1.634
# 3                                              1.679
# 4                                              1.735

# %%
display(df.describe())
# Out:
#               Year  Birth rate, crude (per 1,000 people)  \
# count  12449.00000                          11440.000000
# mean    1989.00000                             28.643276
# std       17.03007                             13.131893
# min     1960.00000                              6.900000
# 25%     1974.00000                             16.600000
# 50%     1989.00000                             27.545500
# 75%     2004.00000                             40.881250
# max     2018.00000                             58.227000
#
#        Death rate, crude (per 1,000 people)  \
# count                          11416.000000
# mean                              10.588539
# std                                5.489382
# min                                1.127000
# 25%                                6.863750
# 50%                                9.200000
# 75%                               12.687000
# max                               54.444000
#
#        Electric power consumption (kWh per capita)     GDP (USD)  \
# count                                  5848.000000  9.578000e+03
# mean                                   3175.294686  1.700740e+11
# std                                    4467.139298  8.979866e+11
# min                                       0.000000  8.824450e+06
# 25%                                     390.385750  1.393010e+09
# 50%                                    1541.895000  7.275305e+09
# 75%                                    4313.767500  4.857782e+10
# max                                   54799.200000  2.050000e+13
#
#        GDP per capita (USD)  Individuals using the Internet (% of population)  \
# count           9575.000000                                       5064.000000
# mean            8231.812259                                         23.334471
# std            16173.539954                                         28.319388
# min               34.790600                                          0.000000
# 25%              513.145500                                          0.594949
# 50%             1852.810000                                          8.406225
# 75%             7774.565000                                         41.295950
# max           189171.000000                                        100.000000
#
#        Infant mortality rate (per 1,000 live births)  \
# count                                    9984.000000
# mean                                       51.704437
# std                                        46.131039
# min                                         1.400000
# 25%                                        14.475000
# 50%                                        37.000000
# 75%                                        78.200000
# max                                       279.400000
#
#        Life expectancy at birth (years)  \
# count                      11176.000000
# mean                          64.044692
# std                           11.491087
# min                           18.907000
# 25%                           55.917750
# 50%                           67.276000
# 75%                           72.692250
# max                           85.417100
#
#        Population density (people per sq. km of land area)  \
# count                                       11845.000000
# mean                                          318.861370
# std                                          1593.406041
# min                                             0.098625
# 25%                                            19.783400
# 50%                                            64.007500
# 75%                                           144.823000
# max                                         21389.100000
#
#        Unemployment (% of total labor force) (modeled ILO estimate)
# count                                        5208.000000
# mean                                            8.295079
# std                                             6.290703
# min                                             0.140000
# 25%                                             3.687000
# 50%                                             6.775000
# 75%                                            11.212250
# max                                            37.940000

# %%
# sns.histplot("df[Country Name]")
# df[['Country Name','Region','IncomeGroup']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 15 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country                                                       12449 non-null  object
#  1   Country Code                                                  12449 non-null  object
#  2   Region                                                        12449 non-null  object
#  3   IncomeGroup                                                   12449 non-null  object
#  4   Year                                                          12449 non-null  int64
#  5   Birth rate, crude (per 1,000 people)                          11440 non-null  float64
#  6   Death rate, crude (per 1,000 people)                          11416 non-null  float64
#  7   Electric power consumption (kWh per capita)                   5848 non-null   float64
#  8   GDP (USD)                                                     9578 non-null   float64
#  9   GDP per capita (USD)                                          9575 non-null   float64
#  10  Individuals using the Internet (% of population)              5064 non-null   float64
#  11  Infant mortality rate (per 1,000 live births)                 9984 non-null   float64
#  12  Life expectancy at birth (years)                              11176 non-null  float64
#  13  Population density (people per sq. km of land area)           11845 non-null  float64
#  14  Unemployment (% of total labor force) (modeled ILO estimate)  5208 non-null   float64
# dtypes: float64(10), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df[df.isna().any(axis=1)]
# Out:
#            Country Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                       NaN
# 1                                    33.211
# 2                                    33.981
# 3                                    34.809
# 4                                    35.706
# ...                                     ...
# 12444                                47.770
# 12445                                47.876
# 12446                                47.950
# 12447                                47.988
# 12448                                47.996
#
#        Death rate, crude (per 1,000 people)  \
# 0                                       NaN
# 1                                     6.575
# 2                                     6.742
# 3                                     6.929
# 4                                     7.141
# ...                                     ...
# 12444                                13.083
# 12445                                13.419
# 12446                                13.762
# 12447                                14.104
# 12448                                14.441
#
#        Electric power consumption (kWh per capita)     GDP (USD)  \
# 0                                              NaN  1.936300e+10
# 1                                              NaN  2.019180e+10
# 2                                              NaN  1.936260e+10
# 3                                              NaN  1.990710e+10
# 4                                              NaN  2.048490e+10
# ...                                            ...           ...
# 12444                                          NaN  1.217138e+09
# 12445                                          NaN  1.159512e+09
# 12446                                          NaN  1.117602e+09
# 12447                                          NaN  1.096647e+09
# 12448                                          NaN  1.052990e+09
#
#        GDP per capita (USD)  Individuals using the Internet (% of population)  \
# 0                   520.897                                               NaN
# 1                   556.302                                             13.50
# 2                   547.228                                             11.20
# 3                   578.466                                              8.26
# 4                   613.856                                              7.00
# ...                     ...                                               ...
# 12444               281.558                                               NaN
# 12445               277.480                                               NaN
# 12446               276.689                                               NaN
# 12447               280.829                                               NaN
# 12448               278.814                                               NaN
#
#        Infant mortality rate (per 1,000 live births)  \
# 0                                               47.9
# 1                                               49.5
# 2                                               51.2
# 3                                               53.1
# 4                                               55.1
# ...                                              ...
# 12444                                           83.2
# 12445                                           85.7
# 12446                                           88.1
# 12447                                           90.5
# 12448                                           92.8
#
#        Life expectancy at birth (years)  \
# 0                                   NaN
# 1                                64.130
# 2                                63.763
# 3                                63.377
# 4                                62.966
# ...                                 ...
# 12444                            54.849
# 12445                            54.403
# 12446                            53.946
# 12447                            53.483
# 12448                            53.019
#
#        Population density (people per sq. km of land area)  \
# 0                                                56.9378
# 1                                                55.5960
# 2                                                54.1971
# 3                                                52.7121
# 4                                                51.1148
# ...                                                  ...
# 12444                                            11.1745
# 12445                                            10.8019
# 12446                                            10.4413
# 12447                                            10.0944
# 12448                                                NaN
#
#        Unemployment (% of total labor force) (modeled ILO estimate)
# 0                                                  1.542
# 1                                                  1.559
# 2                                                  1.634
# 3                                                  1.679
# 4                                                  1.735
# ...                                                  ...
# 12444                                                NaN
# 12445                                                NaN
# 12446                                                NaN
# 12447                                                NaN
# 12448                                                NaN
#
# [9674 rows x 15 columns]

# %%
# import matplotlib.pyplot as plt
# plt.hist(df['Region'])

# %%
# category_counts = df['Region'].value_counts()
# plt.bar(category_counts.index, category_counts.values)
# plt.show()

# %%
# profile and QA the data Objective One

# %%
df["Population (M)"] = (df["GDP (USD)"] / df["GDP per capita (USD)"])
df["Population (M)"] = df["Population (M)"] / 1_000_000
df.head(10)
# Out:
#        Country Country Code      Region IncomeGroup  Year  \
# 0  Afghanistan          AFG  South Asia  Low income  2018
# 1  Afghanistan          AFG  South Asia  Low income  2017
# 2  Afghanistan          AFG  South Asia  Low income  2016
# 3  Afghanistan          AFG  South Asia  Low income  2015
# 4  Afghanistan          AFG  South Asia  Low income  2014
# 5  Afghanistan          AFG  South Asia  Low income  2013
# 6  Afghanistan          AFG  South Asia  Low income  2012
# 7  Afghanistan          AFG  South Asia  Low income  2011
# 8  Afghanistan          AFG  South Asia  Low income  2010
# 9  Afghanistan          AFG  South Asia  Low income  2009
#
#    Birth rate, crude (per 1,000 people)  Death rate, crude (per 1,000 people)  \
# 0                                   NaN                                   NaN
# 1                                33.211                                 6.575
# 2                                33.981                                 6.742
# 3                                34.809                                 6.929
# 4                                35.706                                 7.141
# 5                                36.670                                 7.380
# 6                                37.690                                 7.645
# 7                                38.750                                 7.936
# 8                                39.829                                 8.250
# 9                                40.903                                 8.584
#
#    Electric power consumption (kWh per capita)     GDP (USD)  \
# 0                                          NaN  1.936300e+10
# 1                                          NaN  2.019180e+10
# 2                                          NaN  1.936260e+10
# 3                                          NaN  1.990710e+10
# 4                                          NaN  2.048490e+10
# 5                                          NaN  2.056110e+10
# 6                                          NaN  2.000160e+10
# 7                                          NaN  1.780430e+10
# 8                                          NaN  1.585660e+10
# 9                                          NaN  1.243910e+10
#
#    GDP per capita (USD)  Individuals using the Internet (% of population)  \
# 0               520.897                                               NaN
# 1               556.302                                          13.50000
# 2               547.228                                          11.20000
# 3               578.466                                           8.26000
# 4               613.856                                           7.00000
# 5               637.165                                           5.90000
# 6               641.872                                           5.45455
# 7               591.162                                           5.00000
# 8               543.303                                           4.00000
# 9               438.076                                           3.55000
#
#    Infant mortality rate (per 1,000 live births)  \
# 0                                           47.9
# 1                                           49.5
# 2                                           51.2
# 3                                           53.1
# 4                                           55.1
# 5                                           57.3
# 6                                           59.5
# 7                                           61.9
# 8                                           64.3
# 9                                           66.8
#
#    Life expectancy at birth (years)  \
# 0                               NaN
# 1                            64.130
# 2                            63.763
# 3                            63.377
# 4                            62.966
# 5                            62.525
# 6                            62.054
# 7                            61.553
# 8                            61.028
# 9                            60.484
#
#    Population density (people per sq. km of land area)  \
# 0                                            56.9378
# 1                                            55.5960
# 2                                            54.1971
# 3                                            52.7121
# 4                                            51.1148
# 5                                            49.4280
# 6                                            47.7306
# 7                                            46.1315
# 8                                            44.7041
# 9                                            43.4930
#
#    Unemployment (% of total labor force) (modeled ILO estimate)  \
# 0                                              1.542
# 1                                              1.559
# 2                                              1.634
# 3                                              1.679
# 4                                              1.735
# 5                                              1.725
# 6                                              1.692
# 7                                              1.984
# 8                                              2.275
# 9                                              2.470
#
#    Population (M)
# 0       37.172416
# 1       36.296472
# 2       35.383058
# 3       34.413604
# 4       33.370856
# 5       32.269663
# 6       31.161353
# 7       30.117464
# 8       29.185556
# 9       28.394845

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 16 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country                                                       12449 non-null  object
#  1   Country Code                                                  12449 non-null  object
#  2   Region                                                        12449 non-null  object
#  3   IncomeGroup                                                   12449 non-null  object
#  4   Year                                                          12449 non-null  int64
#  5   Birth rate, crude (per 1,000 people)                          11440 non-null  float64
#  6   Death rate, crude (per 1,000 people)                          11416 non-null  float64
#  7   Electric power consumption (kWh per capita)                   5848 non-null   float64
#  8   GDP (USD)                                                     9578 non-null   float64
#  9   GDP per capita (USD)                                          9575 non-null   float64
#  10  Individuals using the Internet (% of population)              5064 non-null   float64
#  11  Infant mortality rate (per 1,000 live births)                 9984 non-null   float64
#  12  Life expectancy at birth (years)                              11176 non-null  float64
#  13  Population density (people per sq. km of land area)           11845 non-null  float64
#  14  Unemployment (% of total labor force) (modeled ILO estimate)  5208 non-null   float64
#  15  Population (M)                                                9575 non-null   float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
display(df.describe())
# Out:
#               Year  Birth rate, crude (per 1,000 people)  \
# count  12449.00000                          11440.000000
# mean    1989.00000                             28.643276
# std       17.03007                             13.131893
# min     1960.00000                              6.900000
# 25%     1974.00000                             16.600000
# 50%     1989.00000                             27.545500
# 75%     2004.00000                             40.881250
# max     2018.00000                             58.227000
#
#        Death rate, crude (per 1,000 people)  \
# count                          11416.000000
# mean                              10.588539
# std                                5.489382
# min                                1.127000
# 25%                                6.863750
# 50%                                9.200000
# 75%                               12.687000
# max                               54.444000
#
#        Electric power consumption (kWh per capita)     GDP (USD)  \
# count                                  5848.000000  9.578000e+03
# mean                                   3175.294686  1.700740e+11
# std                                    4467.139298  8.979866e+11
# min                                       0.000000  8.824450e+06
# 25%                                     390.385750  1.393010e+09
# 50%                                    1541.895000  7.275305e+09
# 75%                                    4313.767500  4.857782e+10
# max                                   54799.200000  2.050000e+13
#
#        GDP per capita (USD)  Individuals using the Internet (% of population)  \
# count           9575.000000                                       5064.000000
# mean            8231.812259                                         23.334471
# std            16173.539954                                         28.319388
# min               34.790600                                          0.000000
# 25%              513.145500                                          0.594949
# 50%             1852.810000                                          8.406225
# 75%             7774.565000                                         41.295950
# max           189171.000000                                        100.000000
#
#        Infant mortality rate (per 1,000 live births)  \
# count                                    9984.000000
# mean                                       51.704437
# std                                        46.131039
# min                                         1.400000
# 25%                                        14.475000
# 50%                                        37.000000
# 75%                                        78.200000
# max                                       279.400000
#
#        Life expectancy at birth (years)  \
# count                      11176.000000
# mean                          64.044692
# std                           11.491087
# min                           18.907000
# 25%                           55.917750
# 50%                           67.276000
# 75%                           72.692250
# max                           85.417100
#
#        Population density (people per sq. km of land area)  \
# count                                       11845.000000
# mean                                          318.861370
# std                                          1593.406041
# min                                             0.098625
# 25%                                            19.783400
# 50%                                            64.007500
# 75%                                           144.823000
# max                                         21389.100000
#
#        Unemployment (% of total labor force) (modeled ILO estimate)  \
# count                                        5208.000000
# mean                                            8.295079
# std                                             6.290703
# min                                             0.140000
# 25%                                             3.687000
# 50%                                             6.775000
# 75%                                            11.212250
# max                                            37.940000
#
#        Population (M)
# count     9575.000000
# mean        29.956728
# std        115.803824
# min          0.008913
# 25%          1.051937
# 50%          5.390515
# 75%         17.075158
# max       1391.895280

# %%
hdi = pd.read_csv(R"C:\Users\TAJ\Desktop\World Economic Report\HDI.csv")
wb_hdi_2014 = df.query("Year == 2014").merge(hdi[['iso3','hdi_2014']],how='left', left_on="Country Code", right_on="iso3")
wb_hdi_2014.head()
# Out:
#           Country Country Code                      Region  \
# 0     Afghanistan          AFG                  South Asia
# 1         Albania          ALB       Europe & Central Asia
# 2         Algeria          DZA  Middle East & North Africa
# 3  American Samoa          ASM         East Asia & Pacific
# 4         Andorra          AND       Europe & Central Asia
#
#             IncomeGroup  Year  Birth rate, crude (per 1,000 people)  \
# 0            Low income  2014                                35.706
# 1   Upper middle income  2014                                12.259
# 2   Upper middle income  2014                                25.538
# 3   Upper middle income  2014                                17.500
# 4  High income: nonOECD  2014                                   NaN
#
#    Death rate, crude (per 1,000 people)  \
# 0                                 7.141
# 1                                 7.219
# 2                                 4.709
# 3                                 4.200
# 4                                   NaN
#
#    Electric power consumption (kWh per capita)     GDP (USD)  \
# 0                                          NaN  2.048490e+10
# 1                                      2309.37  1.322820e+10
# 2                                      1362.87  2.140000e+11
# 3                                          NaN  6.430000e+08
# 4                                          NaN  3.350740e+09
#
#    GDP per capita (USD)  Individuals using the Internet (% of population)  \
# 0               613.856                                               7.0
# 1              4578.670                                              60.1
# 2              5493.060                                              29.5
# 3             11525.200                                               NaN
# 4             42300.300                                              95.9
#
#    Infant mortality rate (per 1,000 live births)  \
# 0                                           55.1
# 1                                            8.9
# 2                                           21.8
# 3                                            NaN
# 4                                            3.2
#
#    Life expectancy at birth (years)  \
# 0                            62.966
# 1                            77.813
# 2                            75.878
# 3                               NaN
# 4                               NaN
#
#    Population density (people per sq. km of land area)  \
# 0                                            51.1148
# 1                                           105.4420
# 2                                            16.3425
# 3                                           278.9550
# 4                                           168.5380
#
#    Unemployment (% of total labor force) (modeled ILO estimate)  \
# 0                                              1.735
# 1                                             17.490
# 2                                             10.207
# 3                                                NaN
# 4                                                NaN
#
#    Population (M) iso3  hdi_2014
# 0       33.370856  AFG     0.479
# 1        2.889092  ALB     0.792
# 2       38.958249  DZA     0.735
# 3        0.055791  NaN       NaN
# 4        0.079213  AND     0.871

# %%
# wb = pd.read_excel(R"C:\Users\TAJ\Desktop\world_economic_report\WorldBank.xlsx").rename({"Country Name": "Country"}, axis=1)

# wb["Population (M)"] = (wb["GDP (USD)"] / wb["GDP per capita (USD)"])
# wb["Population (M)"] = wb["Population (M)"] / 1_000_000

# wb_2014 = wb[wb["Year"] == 2014]


# wb_2014 = wb_2014.merge(
#     hdi,
#     on="Country Code",
#     how="left"
# )

# %%
# wb_2014.head()

# %%
# print(wb.columns)
# print(hdi.columns)

# %%
# hdi = hdi.rename(columns={"iso3": "Country Code"})

# %%
hdi.head()
# Out:
#   iso3               country    hdicode region  hdi_rank_2021  hdi_1990  \
# 0  AFG           Afghanistan        Low     SA          180.0     0.273
# 1  AGO                Angola     Medium    SSA          148.0       NaN
# 2  ALB               Albania       High    ECA           67.0     0.647
# 3  AND               Andorra  Very High    NaN           40.0       NaN
# 4  ARE  United Arab Emirates  Very High     AS           26.0     0.728
#
#    hdi_1991  hdi_1992  hdi_1993  hdi_1994  ...  mf_2012  mf_2013  mf_2014  \
# 0     0.279     0.287     0.297     0.292  ...     1.86     1.88     1.66
# 1       NaN       NaN       NaN       NaN  ...     4.09     4.53     3.97
# 2     0.629     0.614     0.617     0.624  ...    12.44    11.49    13.14
# 3       NaN       NaN       NaN       NaN  ...      NaN      NaN      NaN
# 4     0.739     0.742     0.748     0.755  ...    49.56    49.68    55.49
#
#    mf_2015  mf_2016  mf_2017  mf_2018  mf_2019  mf_2020  mf_2021
# 0     1.62     1.66     1.41     1.32     1.38     1.38     1.38
# 1     3.59     2.79     2.64     2.28     2.18     2.18     2.18
# 2    12.61    14.39    14.46    12.85    12.96    12.96    12.96
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4    59.76    64.95    75.61    65.97    68.95    68.95    68.95
#
# [5 rows x 1008 columns]

# %%
wb_hdi_2014.describe()
# Out:
#          Year  Birth rate, crude (per 1,000 people)  \
# count   211.0                            204.000000
# mean   2014.0                             20.859378
# std       0.0                             10.280302
# min    2014.0                              7.900000
# 25%    2014.0                             11.975000
# 50%    2014.0                             17.799000
# 75%    2014.0                             28.663750
# max    2014.0                             47.988000
#
#        Death rate, crude (per 1,000 people)  \
# count                            204.000000
# mean                               7.693044
# std                                2.706626
# min                                1.127000
# 25%                                5.836250
# 50%                                7.501500
# 75%                                9.219250
# max                               16.433000
#
#        Electric power consumption (kWh per capita)     GDP (USD)  \
# count                                   139.000000  2.010000e+02
# mean                                   4270.600563  3.907779e+11
# std                                    5981.464101  1.546117e+12
# min                                      39.055800  3.729180e+07
# 25%                                     858.174500  6.047810e+09
# 50%                                    2588.300000  3.133500e+10
# 75%                                    5478.100000  2.060000e+11
# max                                   53832.500000  1.750000e+13
#
#        GDP per capita (USD)  Individuals using the Internet (% of population)  \
# count            201.000000                                        199.000000
# mean           17779.147856                                         45.738525
# std            27113.375249                                         28.934518
# min              248.845000                                          0.990000
# 25%             2163.160000                                         17.730000
# 50%             6684.800000                                         46.160000
# 75%            20258.000000                                         69.890000
# max           189171.000000                                         98.160000
#
#        Infant mortality rate (per 1,000 live births)  \
# count                                     190.000000
# mean                                       23.844211
# std                                        21.750467
# min                                         1.800000
# 25%                                         6.800000
# 50%                                        15.050000
# 75%                                        36.775000
# max                                        93.000000
#
#        Life expectancy at birth (years)  \
# count                        197.000000
# mean                          71.832723
# std                            8.130386
# min                           49.891000
# 25%                           66.370000
# 50%                           73.429000
# 75%                           77.583000
# max                           83.980500
#
#        Population density (people per sq. km of land area)  \
# count                                         208.000000
# mean                                          424.474198
# std                                          1986.297846
# min                                             0.137154
# 25%                                            36.550050
# 50%                                            88.684650
# 75%                                           210.380000
# max                                         19478.800000
#
#        Unemployment (% of total labor force) (modeled ILO estimate)  \
# count                                         186.000000
# mean                                            8.077554
# std                                             6.019114
# min                                             0.190000
# 25%                                             3.767250
# 50%                                             6.513000
# 75%                                            10.809000
# max                                            28.030000
#
#        Population (M)    hdi_2014
# count      201.000000  188.000000
# mean        35.668407    0.709527
# std        136.957226    0.152831
# min          0.010972    0.370000
# 25%          1.174332    0.581250
# 50%          7.130572    0.732000
# 75%         23.589826    0.824750
# max       1359.233706    0.952000

# %%
# Prepare for visualization

# %%
gdp_pivot = df.pivot_table(index="Year", columns="Region", values="GDP (USD)", aggfunc="sum")
gdp_pivot.head()
# Out:
# Region  East Asia & Pacific  Europe & Central Asia  Latin America & Caribbean  \
# Year
# 1960           1.464117e+11           2.834935e+11               5.739654e+10
# 1961           1.466530e+11           3.017402e+11               6.076987e+10
# 1962           1.499092e+11           3.299221e+11               9.396297e+10
# 1963           1.672525e+11           3.638093e+11               9.482963e+10
# 1964           1.921179e+11           4.028910e+11               1.056766e+11
#
# Region  Middle East & North Africa  North America    South Asia  \
# Year
# 1960                  1.410025e+10   5.430845e+11  4.746783e+10
# 1961                  1.480286e+10   6.046452e+11  5.062976e+10
# 1962                  1.464985e+10   6.479622e+11  5.403093e+10
# 1963                  1.646011e+10   6.848096e+11  6.077062e+10
# 1964                  1.817288e+10   7.362342e+11  6.960261e+10
#
# Region  Sub-Saharan Africa
# Year
# 1960          2.648878e+10
# 1961          2.753489e+10
# 1962          2.984425e+10
# 1963          3.419779e+10
# 1964          3.338035e+10

# %%
pop_pivot = df.pivot_table(index="Year", columns="Region", values="Population (M)", aggfunc="sum")
pop_pivot.head()
# Out:
# Region  East Asia & Pacific  Europe & Central Asia  Latin America & Caribbean  \
# Year
# 1960             872.149068             280.746688                 186.852628
# 1961             871.192827             283.656647                 192.312725
# 1962             881.036241             286.741448                 219.093142
# 1963             902.065879             289.789614                 225.199250
# 1964             922.572657             292.833206                 231.411905
#
# Region  Middle East & North Africa  North America  South Asia  \
# Year
# 1960                     59.303286     180.615844  572.526561
# 1961                     60.945298     201.909874  584.618194
# 1962                     62.667579     205.167974  597.165027
# 1963                     64.416446     208.372005  610.162283
# 1964                     66.231025     211.318874  623.598506
#
# Region  Sub-Saharan Africa
# Year
# 1960            168.518542
# 1961            172.577530
# 1962            177.066655
# 1963            181.468995
# 1964            186.049084

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Country', 'Country Code', 'Region', 'IncomeGroup', 'Year',
#        'Birth rate, crude (per 1,000 people)',
#        'Death rate, crude (per 1,000 people)',
#        'Electric power consumption (kWh per capita)', 'GDP (USD)',
#        'GDP per capita (USD)',
#        'Individuals using the Internet (% of population)',
#        'Infant mortality rate (per 1,000 live births)',
#        'Life expectancy at birth (years)',
#        'Population density (people per sq. km of land area)',
#        'Unemployment (% of total labor force) (modeled ILO estimate)',
#        'Population (M)'],
#       dtype='object')

# %%
wb_hdi_by_region = wb_hdi_2014.groupby(
    "Region"
).agg({"hdi_2014": "mean"}).sort_values("hdi_2014", ascending=False)
wb_hdi_by_region.head()
# Out:
#                             hdi_2014
# Region
# North America               0.922000
# Europe & Central Asia       0.845320
# Latin America & Caribbean   0.739697
# Middle East & North Africa  0.736619
# East Asia & Pacific         0.729963

# %%
# Visualize the Data

# %%
# Stack area
fig, ax = plt.subplots()

ax.stackplot(
    gdp_pivot.index,
    [gdp_pivot[region] / 1_000_000_000_000 for region in gdp_pivot.
     iloc[-1].sort_values(ascending=False).index],
     labels=gdp_pivot.iloc[-1].sort_values(ascending=False).index
)

ax.legend(loc="upper left")
plt.title("GDP has Grows Exponentially Over Time")
ax.set_ylabel("GDP (Trillions)")
plt.show()

# %%
gdp_pivot.iloc[-1].sort_values(ascending=False).index
# Out:
# Index(['East Asia & Pacific', 'Europe & Central Asia', 'North America',
#        'Latin America & Caribbean', 'South Asia', 'Middle East & North Africa',
#        'Sub-Saharan Africa'],
#       dtype='object', name='Region')

# %%
# Stack area
fig, ax = plt.subplots()

ax.stackplot(
    pop_pivot.index,
    [pop_pivot[region] / 1_000 for region in pop_pivot.
     iloc[-1].sort_values(ascending=False).index],
     labels=pop_pivot.iloc[-1].sort_values(ascending=False).index
)

ax.legend(loc="upper left")
ax.set_title("Population has surged from 2 billion to 7.5 billions")
ax.set_ylabel("Population (Trillions)")
plt.show()

# %%
import matplotlib.ticker as mticker

fig, ax = plt.subplots()

minsize = min(wb_hdi_2014['Population (M)'])
maxsize = max(wb_hdi_2014['Population (M)'])

sns.scatterplot(
    data=wb_hdi_2014,
    x="Life expectancy at birth (years)",
    y="GDP per capita (USD)",
    size="Population (M)",
    sizes=(minsize, maxsize),
    hue="Region",
    # legend="False"
).set(title="Life Expectancy Increases as Countries get richer",yscale="log")

ax.yaxis.set_major_formatter(mticker.ScalarFormatter())

# %%
wb_hdi_2014.columns = wb_hdi_2014.columns.str.strip()
wb_hdi_2014.columns
# Out:
# Index(['Country', 'Country Code', 'Region', 'IncomeGroup', 'Year',
#        'Birth rate, crude (per 1,000 people)',
#        'Death rate, crude (per 1,000 people)',
#        'Electric power consumption (kWh per capita)', 'GDP (USD)',
#        'GDP per capita (USD)',
#        'Individuals using the Internet (% of population)',
#        'Infant mortality rate (per 1,000 live births)',
#        'Life expectancy at birth (years)',
#        'Population density (people per sq. km of land area)',
#        'Unemployment (% of total labor force) (modeled ILO estimate)',
#        'Population (M)', 'iso3', 'hdi_2014'],
#       dtype='object')

# %%
wb_hdi_2014.head()
# Out:
#           Country Country Code                      Region  \
# 0     Afghanistan          AFG                  South Asia
# 1         Albania          ALB       Europe & Central Asia
# 2         Algeria          DZA  Middle East & North Africa
# 3  American Samoa          ASM         East Asia & Pacific
# 4         Andorra          AND       Europe & Central Asia
#
#             IncomeGroup  Year  Birth rate, crude (per 1,000 people)  \
# 0            Low income  2014                                35.706
# 1   Upper middle income  2014                                12.259
# 2   Upper middle income  2014                                25.538
# 3   Upper middle income  2014                                17.500
# 4  High income: nonOECD  2014                                   NaN
#
#    Death rate, crude (per 1,000 people)  \
# 0                                 7.141
# 1                                 7.219
# 2                                 4.709
# 3                                 4.200
# 4                                   NaN
#
#    Electric power consumption (kWh per capita)     GDP (USD)  \
# 0                                          NaN  2.048490e+10
# 1                                      2309.37  1.322820e+10
# 2                                      1362.87  2.140000e+11
# 3                                          NaN  6.430000e+08
# 4                                          NaN  3.350740e+09
#
#    GDP per capita (USD)  Individuals using the Internet (% of population)  \
# 0               613.856                                               7.0
# 1              4578.670                                              60.1
# 2              5493.060                                              29.5
# 3             11525.200                                               NaN
# 4             42300.300                                              95.9
#
#    Infant mortality rate (per 1,000 live births)  \
# 0                                           55.1
# 1                                            8.9
# 2                                           21.8
# 3                                            NaN
# 4                                            3.2
#
#    Life expectancy at birth (years)  \
# 0                            62.966
# 1                            77.813
# 2                            75.878
# 3                               NaN
# 4                               NaN
#
#    Population density (people per sq. km of land area)  \
# 0                                            51.1148
# 1                                           105.4420
# 2                                            16.3425
# 3                                           278.9550
# 4                                           168.5380
#
#    Unemployment (% of total labor force) (modeled ILO estimate)  \
# 0                                              1.735
# 1                                             17.490
# 2                                             10.207
# 3                                                NaN
# 4                                                NaN
#
#    Population (M) iso3  hdi_2014
# 0       33.370856  AFG     0.479
# 1        2.889092  ALB     0.792
# 2       38.958249  DZA     0.735
# 3        0.055791  NaN       NaN
# 4        0.079213  AND     0.871

# %%
# import matplotlib.pyplot as plt

# plt.scatter(
#     wb_hdi_2014["Life expectancy at birth (years)"],
#     wb_hdi_2014["GDP per capita (USD)"],
#     s=wb_hdi_2014["Population (M)"] * 5,
#     c=wb_hdi_2014["Region_Code"],
#     alpha=0.6
# )
# plt.yscale("log")
# plt.xlabel("Life Expectancy")
# plt.ylabel("GDP per Capita (log)")

# %%
# wb_hdi_2014.info()

# %%
wb_hdi_by_region.plot.bar(title="HDI by Region", ylabel="Human Development Index")
plt.show()

# %%
sns.scatterplot(
    data=wb_hdi_2014.query("Country != 'Iceland'"),
    x="Electric power consumption (kWh per capita)",
    y="GDP per capita (USD)",
    hue="hdi_2014",
    palette="coolwarm_r"

).set(title="Electricity Drives Development")
# Out:
# [Text(0.5, 1.0, 'Electricity Drives Development')]

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(8, 12))
gs = gridspec.GridSpec(nrows=12, ncols=6)

stack1_list = ['#66C2A5', '#fC8D62', '#8DA0CB', '#E78AC3', '#A6D854', '#FFD92F', '#B3B3B3']
stack2_list = ['#66C2A5', '#A6D854','#B3B3B3', '#fC8D62', '#E78AC3', '#8DA0CB', '#FFD92F']
bar_list = ['#8DA0CB', '#fC8D62', '#E78AC3', '#FFD92F', '#66C2A5', '#A6D854', '#B3B3B3']
bar_list_5 = bar_list[:5]
bubble_list = ['#A6D854', '#fC8D62', '#FFD92F', '#66C2A5', '#B3B3B3', '#E78AC3', '#8DA0CB']

# add title
ax1 = fig.add_subplot(gs[0:4, 0:3])
ax1.stackplot(
    gdp_pivot.index,
    [gdp_pivot[region] / 1_000_000_000_000 for region in gdp_pivot.
     iloc[-1].sort_values(ascending=False).index],
     labels=gdp_pivot.iloc[-1].sort_values(ascending=False).index,
     colors=stack1_list
)

ax1.legend(loc="upper left")
ax1.set_title("GDP has Grows Exponentially Over Time")
ax1.set_ylabel("GDP (Trillions)")

ax2 = fig.add_subplot(gs[0:4, 3:6])
ax2.stackplot(
    pop_pivot.index,
    [pop_pivot[region] / 1_000 for region in pop_pivot.
     iloc[-1].sort_values(ascending=False).index],
     labels=pop_pivot.iloc[-1].sort_values(ascending=False).index,
     colors=stack2_list
)

ax2.legend(loc="upper left")
ax2.set_title("Population has surged from 2 billion to 7.5 billions")
ax2.set_ylabel("Population (Trillions)")

ax3 = fig.add_subplot(gs[4:8, :])
minsize = min(wb_hdi_2014['Population (M)'])
maxsize = max(wb_hdi_2014['Population (M)'])

sns.scatterplot(
    data=wb_hdi_2014,
    x="Life expectancy at birth (years)",
    y="GDP per capita (USD)",
    size="Population (M)",
    sizes=(minsize, maxsize),
    hue="Region",
    ax=ax3,
    palette=bubble_list
    # legend="False"
).set(title="Life Expectancy Increases as Countries get richer",yscale="log")

ax3.yaxis.set_major_formatter(mticker.ScalarFormatter())

# ax4 = fig.add_subplot(gs[8:12, 0:3])
# ax4 = wb_hdi_by_region.plot.bar(title="HDI by Region", ylabel="Human Development Index", color=bar_list)
# ax4 = fig.add_subplot(gs[8:12, 0:3])
# wb_hdi_by_region.plot.bar(
#     ax=ax4,
#     title="HDI by Region",
#     ylabel="Human Development Index",
#     color=bar_list_5
# )
# ax4 = fig.add_subplot(gs[8:12, 0:3])
# ax4 = wb_hdi_by_region.plot.bar(title="HDI by Region", ylabel="Human Development Index")

ax4 = fig.add_subplot(gs[8:12, 0:3])

# Get the number of regions
n_regions = len(wb_hdi_by_region)

# Use first n colors from bar_list
colors_to_use = bar_list[:n_regions]

# Use matplotlib bar directly
bars = ax4.bar(
    range(len(wb_hdi_by_region)),
    wb_hdi_by_region['hdi_2014'],
    color=colors_to_use
)

# Set the x-tick labels to region names
ax4.set_xticks(range(len(wb_hdi_by_region)))
ax4.set_xticklabels(wb_hdi_by_region.index, rotation=45, ha='right')
ax4.set_title("HDI by Region")
ax4.set_ylabel("Human Development Index")

ax5 = fig.add_subplot(gs[8:12, 3:6])
sns.scatterplot(
    data=wb_hdi_2014.query("Country != 'Iceland'"),
    x="Electric power consumption (kWh per capita)",
    y="GDP per capita (USD)",
    hue="hdi_2014",
    palette="coolwarm_r",
    ax=ax5

).set(title="Electricity Drives Development")

fig.subplots_adjust(wspace=4, hspace=4)

# list(sns.color_palette("Set2").as_hex())

# %%
print(wb_hdi_by_region.columns)
# Out:
# Index(['hdi_2014'], dtype='object')
